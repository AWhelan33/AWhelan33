# %% [markdown]
# # Geographic data plotting - Wind Turbines in the UK
# This project uses data on the locations of wind turbines in the UK to plot them on a point map.
# The inspiration for the project came from the 30 day map challenge here https://30daymapchallenge.com/.
# The challenge ran in November 2022 and whilst I missed the actual timing of it I felt it was a good challenge to set myself over a longer period of time.
# The first prompt of the challenge is Points.
# When trying to think of what data I could plot a leaflet dropped through my door about wind turbine plans for my local area and so I decided this might be a good topic for plotting points. The locations of wind turbines in the UK. Initially Onshore turbines but this may extend to off shore.
# The data is sourced from wikipedia https://en.wikipedia.org/wiki/List_of_onshore_wind_farms_in_the_United_Kingdom
# and i'm using this tutorial on how to plot geographic data with python
# https://towardsdatascience.com/easy-steps-to-plot-geographic-data-on-a-map-python-11217859a2db
# So without further ado lets get plotting.

# %%
# import standard libraries plus those for data scraping
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# define the data scraping function
def scrapeDataAndCreateDataFrame(url, tableNo):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    table = soup.find_all('table', {'class': "wikitable"})[tableNo]
    df = pd.read_html(str(table))
    df = pd.DataFrame(df[0])
    return df

# %%
# Set the url
url = 'https://en.wikipedia.org/wiki/List_of_onshore_wind_farms_in_the_United_Kingdom'

# %%
# Scrape the data
dfEng = scrapeDataAndCreateDataFrame(url, 0)

# %%
# Check the data frame information
dfEng.head()
# Out:
#         Wind farm          County  \
# 0        Red Tile  Cambridgeshire
# 1        Frodsham        Cheshire
# 2      Bears Down        Cornwall
# 3  Cold Northcott        Cornwall
# 4    Four Burrows        Cornwall
#
#                                          Coordinates  \
# 0  .mw-parser-output .geo-default,.mw-parser-outp...
# 1     53°17′46″N 02°45′28″W﻿ / ﻿53.29611°N 2.75778°W
# 2     50°28′23″N 04°57′11″W﻿ / ﻿50.47306°N 4.95306°W
# 3     50°38′14″N 04°31′07″W﻿ / ﻿50.63722°N 4.51861°W
# 4     50°17′30″N 05°08′44″W﻿ / ﻿50.29167°N 5.14556°W
#
#   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Model  \
# 0                                       REpower MM82
# 1                                                NaN
# 2                                         Bonus B600
# 3                                        WEG MS3-300
# 4                                         Bonus B300
#
#    Power perturbine(MW)  No.  Cap. (MW)  Online                    Developer  \
# 0                  2.00   12      24.00    2007                Wind Prospect
# 1                  2.65   19      50.35    2017          Peel Wind Power Ltd
# 2                  0.60   16       9.60    2001            npower renewables
# 3                  0.30   22       6.80    1993  First Windfarm Holdings Ltd
# 4                  0.30   15       4.50    1998                   Ecogen Ltd
#
#              Operator                     Owner Website
# 0  Cumbria Wind Farms                    EDF EN     [1]
# 1                   -                       NaN     [2]
# 2              Innogy                    Innogy     [3]
# 3  Cumbria Wind Farms  First Wind Farm Holdings     [4]
# 4                 RES                       RES     [5]

# %%
dfWales = scrapeDataAndCreateDataFrame(url, 3)
dfScot = scrapeDataAndCreateDataFrame(url, 2)
dfNI = scrapeDataAndCreateDataFrame(url, 1)

# %%
merged_df = pd.concat([dfEng, dfWales, dfScot, dfNI])

# %%
merged_df.head()
# Out:
#         Wind farm          County  \
# 0        Red Tile  Cambridgeshire
# 1        Frodsham        Cheshire
# 2      Bears Down        Cornwall
# 3  Cold Northcott        Cornwall
# 4    Four Burrows        Cornwall
#
#                                          Coordinates  \
# 0  .mw-parser-output .geo-default,.mw-parser-outp...
# 1     53°17′46″N 02°45′28″W﻿ / ﻿53.29611°N 2.75778°W
# 2     50°28′23″N 04°57′11″W﻿ / ﻿50.47306°N 4.95306°W
# 3     50°38′14″N 04°31′07″W﻿ / ﻿50.63722°N 4.51861°W
# 4     50°17′30″N 05°08′44″W﻿ / ﻿50.29167°N 5.14556°W
#
#   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Model  \
# 0                                       REpower MM82
# 1                                                NaN
# 2                                         Bonus B600
# 3                                        WEG MS3-300
# 4                                         Bonus B300
#
#    Power perturbine(MW)  No.  Cap. (MW)  Online                    Developer  \
# 0                  2.00   12      24.00    2007                Wind Prospect
# 1                  2.65   19      50.35    2017          Peel Wind Power Ltd
# 2                  0.60   16       9.60    2001            npower renewables
# 3                  0.30   22       6.80    1993  First Windfarm Holdings Ltd
# 4                  0.30   15       4.50    1998                   Ecogen Ltd
#
#              Operator                     Owner Website Model  \
# 0  Cumbria Wind Farms                    EDF EN     [1]   NaN
# 1                   -                       NaN     [2]   NaN
# 2              Innogy                    Innogy     [3]   NaN
# 3  Cumbria Wind Farms  First Wind Farm Holdings     [4]   NaN
# 4                 RES                       RES     [5]   NaN
#
#    Power per turbine (MW)
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
# Drop the unecessary columns
df = merged_df.drop(['County'], axis=1)

# %%
df.columns
# Out:
# Index(['Wind farm', 'Coordinates',
#        '.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Model',
#        'Power perturbine(MW)', 'No.', 'Cap. (MW)', 'Online', 'Developer',
#        'Operator', 'Owner', 'Website', 'Model', 'Power per turbine (MW)'],
#       dtype='object')

# %%
df = df.drop(['Developer', 'Operator', 'Owner', 'Website'], axis=1)

# %%
df.head()
# Out:
#         Wind farm                                        Coordinates  \
# 0        Red Tile  .mw-parser-output .geo-default,.mw-parser-outp...
# 1        Frodsham     53°17′46″N 02°45′28″W﻿ / ﻿53.29611°N 2.75778°W
# 2      Bears Down     50°28′23″N 04°57′11″W﻿ / ﻿50.47306°N 4.95306°W
# 3  Cold Northcott     50°38′14″N 04°31′07″W﻿ / ﻿50.63722°N 4.51861°W
# 4    Four Burrows     50°17′30″N 05°08′44″W﻿ / ﻿50.29167°N 5.14556°W
#
#   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Model  \
# 0                                       REpower MM82
# 1                                                NaN
# 2                                         Bonus B600
# 3                                        WEG MS3-300
# 4                                         Bonus B300
#
#    Power perturbine(MW)  No.  Cap. (MW)  Online Model  Power per turbine (MW)
# 0                  2.00   12      24.00    2007   NaN                     NaN
# 1                  2.65   19      50.35    2017   NaN                     NaN
# 2                  0.60   16       9.60    2001   NaN                     NaN
# 3                  0.30   22       6.80    1993   NaN                     NaN
# 4                  0.30   15       4.50    1998   NaN                     NaN

# %%
df[['Coordinates1', 'Coordinates2']] = df.Coordinates.str.split("/", expand = True)
print(df.head())
# Out:
#         Wind farm                                        Coordinates  \
# 0        Red Tile  .mw-parser-output .geo-default,.mw-parser-outp...
# 1        Frodsham     53°17′46″N 02°45′28″W﻿ / ﻿53.29611°N 2.75778°W
# 2      Bears Down     50°28′23″N 04°57′11″W﻿ / ﻿50.47306°N 4.95306°W
# 3  Cold Northcott     50°38′14″N 04°31′07″W﻿ / ﻿50.63722°N 4.51861°W
# 4    Four Burrows     50°17′30″N 05°08′44″W﻿ / ﻿50.29167°N 5.14556°W
#
#   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Model  \
# 0                                       REpower MM82
# 1                                                NaN
# 2                                         Bonus B600
# 3                                        WEG MS3-300
# 4                                         Bonus B300
#
#    Power perturbine(MW)  No.  Cap. (MW)  Online Model  Power per turbine (MW)  \
# 0                  2.00   12      24.00    2007   NaN                     NaN
# 1                  2.65   19      50.35    2017   NaN                     NaN
# 2                  0.60   16       9.60    2001   NaN                     NaN
# 3                  0.30   22       6.80    1993   NaN                     NaN
# 4                  0.30   15       4.50    1998   NaN                     NaN
#
#                                         Coordinates1            Coordinates2
# 0  .mw-parser-output .geo-default,.mw-parser-outp...   ﻿52.45056°N 0.00750°W
# 1                            53°17′46″N 02°45′28″W﻿    ﻿53.29611°N 2.75778°W
# 2                            50°28′23″N 04°57′11″W﻿    ﻿50.47306°N 4.95306°W
# 3                            50°38′14″N 04°31′07″W﻿    ﻿50.63722°N 4.51861°W
# 4                            50°17′30″N 05°08′44″W﻿    ﻿50.29167°N 5.14556°W

# %%
df[['coordinates1Northing', 'coordinates1Westing']] = df.Coordinates1.str.split("N ", expand = True)

# %%
df.to_csv('windTurbinesOnshore.csv', index=False)

# %%
df[df.index.duplicated()]
# Out:
#                            Wind farm  \
# 0                          Llyn Alaw
# 1     Alltwalis (formerly Blaengwen)
# 2                         Blaen Bowi
# 3                         Parc Cynog
# 4   Pendine (Parc Cynog Extension I)
# ..                               ...
# 17         Lendrum's Bridge Phase II
# 18           Lough Hill Resubmission
# 19                         Owenreagh
# 20               Owenreagh Extension
# 21                   Slieve Divena 1
#
#                                        Coordinates  \
# 0   53°21′48″N 04°26′59″W﻿ / ﻿53.36333°N 4.44972°W
# 1   51°58′42″N 04°15′03″W﻿ / ﻿51.97833°N 4.25083°W
# 2   51°59′17″N 04°26′43″W﻿ / ﻿51.98806°N 4.44528°W
# 3   51°45′33″N 04°32′40″W﻿ / ﻿51.75917°N 4.54444°W
# 4   51°45′33″N 04°32′40″W﻿ / ﻿51.75917°N 4.54444°W
# ..                                             ...
# 17  54°26′12″N 07°20′42″W﻿ / ﻿54.43667°N 7.34500°W
# 18  54°37′37″N 07°36′21″W﻿ / ﻿54.62694°N 7.60583°W
# 19  54°48′30″N 07°19′54″W﻿ / ﻿54.80833°N 7.33167°W
# 20  54°48′30″N 07°19′54″W﻿ / ﻿54.80833°N 7.33167°W
# 21  54°30′27″N 07°06′19″W﻿ / ﻿54.50750°N 7.10528°W
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Model  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
#     Power perturbine(MW)  No.  Cap. (MW)  Online            Model  \
# 0                    NaN   34       20.4    1997       Bonus B600
# 1                    NaN   10       23.0    2009  Siemens SWT-2.3
# 2                    NaN    3        3.9    2002       Nordex N60
# 3                    NaN    5        3.6    2001        NEG Micon
# 4                    NaN    6        4.8    2009      Enercon E48
# ..                   ...  ...        ...     ...              ...
# 17                   NaN   11        7.3    2002       Vestas V47
# 18                   NaN    6        7.8    2007  Siemens SWT-1.3
# 19                   NaN   10        5.0    1997         Zond Z40
# 20                   NaN    6        5.1    2008       Vestas V52
# 21                   NaN   12       30.0    2009       Nordex N80
#
#     Power per turbine (MW)             Coordinates1            Coordinates2  \
# 0                     0.60  53°21′48″N 04°26′59″W﻿    ﻿53.36333°N 4.44972°W
# 1                     2.30  51°58′42″N 04°15′03″W﻿    ﻿51.97833°N 4.25083°W
# 2                     1.30  51°59′17″N 04°26′43″W﻿    ﻿51.98806°N 4.44528°W
# 3                     0.72  51°45′33″N 04°32′40″W﻿    ﻿51.75917°N 4.54444°W
# 4                     0.80  51°45′33″N 04°32′40″W﻿    ﻿51.75917°N 4.54444°W
# ..                     ...                      ...                     ...
# 17                    0.66  54°26′12″N 07°20′42″W﻿    ﻿54.43667°N 7.34500°W
# 18                    1.30  54°37′37″N 07°36′21″W﻿    ﻿54.62694°N 7.60583°W
# 19                    0.50  54°48′30″N 07°19′54″W﻿    ﻿54.80833°N 7.33167°W
# 20                    0.85  54°48′30″N 07°19′54″W﻿    ﻿54.80833°N 7.33167°W
# 21                    2.50  54°30′27″N 07°06′19″W﻿    ﻿54.50750°N 7.10528°W
#
#    coordinates1Northing coordinates1Westing
# 0             53°21′48″        04°26′59″W﻿
# 1             51°58′42″        04°15′03″W﻿
# 2             51°59′17″        04°26′43″W﻿
# 3             51°45′33″        04°32′40″W﻿
# 4             51°45′33″        04°32′40″W﻿
# ..                  ...                 ...
# 17            54°26′12″        07°20′42″W﻿
# 18            54°37′37″        07°36′21″W﻿
# 19            54°48′30″        07°19′54″W﻿
# 20            54°48′30″        07°19′54″W﻿
# 21            54°30′27″        07°06′19″W﻿
#
# [70 rows x 13 columns]

# %%
data = pd.read_csv('windTurbinesOnshore.csv')

# %%
df = data

# %%
df.head()
# Out:
#         Wind farm                                     Coordinates  \
# 0        Red Tile                            52.45056°N 0.00750°W
# 1        Frodsham  53°17′46″N 02°45′28″W﻿ / ﻿53.29611°N 2.75778°W
# 2      Bears Down  50°28′23″N 04°57′11″W﻿ / ﻿50.47306°N 4.95306°W
# 3  Cold Northcott  50°38′14″N 04°31′07″W﻿ / ﻿50.63722°N 4.51861°W
# 4    Four Burrows  50°17′30″N 05°08′44″W﻿ / ﻿50.29167°N 5.14556°W
#
#   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Model  \
# 0                                       REpower MM82
# 1                                                NaN
# 2                                         Bonus B600
# 3                                        WEG MS3-300
# 4                                         Bonus B300
#
#    Power perturbine(MW)  No.  Cap. (MW)  Online Model  Power per turbine (MW)  \
# 0                  2.00   12      24.00    2007   NaN                     NaN
# 1                  2.65   19      50.35    2017   NaN                     NaN
# 2                  0.60   16       9.60    2001   NaN                     NaN
# 3                  0.30   22       6.80    1993   NaN                     NaN
# 4                  0.30   15       4.50    1998   NaN                     NaN
#
#                                         Coordinates1            Coordinates2  \
# 0  .mw-parser-output .geo-default,.mw-parser-outp...   ﻿52.45056°N 0.00750°W
# 1                            53°17′46″N 02°45′28″W﻿    ﻿53.29611°N 2.75778°W
# 2                            50°28′23″N 04°57′11″W﻿    ﻿50.47306°N 4.95306°W
# 3                            50°38′14″N 04°31′07″W﻿    ﻿50.63722°N 4.51861°W
# 4                            50°17′30″N 05°08′44″W﻿    ﻿50.29167°N 5.14556°W
#
#   coordinates1Northing coordinates1Westing
# 0            52°27′02″        00°00′27″W﻿
# 1            53°17′46″        02°45′28″W﻿
# 2            50°28′23″        04°57′11″W﻿
# 3            50°38′14″        04°31′07″W﻿
# 4            50°17′30″        05°08′44″W﻿

# %%
from dms2dec.dms_convert import dms2dec

df['lat'] = df.loc[df['coordinates1Northing'].notnull(), 'coordinates1Northing'].apply(dms2dec)
df['long'] = df.loc[df['coordinates1Westing'].notnull(), 'coordinates1Westing'].apply(dms2dec)

# %%
df.head()
# Out:
#         Wind farm                                     Coordinates  \
# 0        Red Tile                            52.45056°N 0.00750°W
# 1        Frodsham  53°17′46″N 02°45′28″W﻿ / ﻿53.29611°N 2.75778°W
# 2      Bears Down  50°28′23″N 04°57′11″W﻿ / ﻿50.47306°N 4.95306°W
# 3  Cold Northcott  50°38′14″N 04°31′07″W﻿ / ﻿50.63722°N 4.51861°W
# 4    Four Burrows  50°17′30″N 05°08′44″W﻿ / ﻿50.29167°N 5.14556°W
#
#   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Model  \
# 0                                       REpower MM82
# 1                                                NaN
# 2                                         Bonus B600
# 3                                        WEG MS3-300
# 4                                         Bonus B300
#
#    Power perturbine(MW)  No.  Cap. (MW)  Online Model  Power per turbine (MW)  \
# 0                  2.00   12      24.00    2007   NaN                     NaN
# 1                  2.65   19      50.35    2017   NaN                     NaN
# 2                  0.60   16       9.60    2001   NaN                     NaN
# 3                  0.30   22       6.80    1993   NaN                     NaN
# 4                  0.30   15       4.50    1998   NaN                     NaN
#
#                                         Coordinates1            Coordinates2  \
# 0  .mw-parser-output .geo-default,.mw-parser-outp...   ﻿52.45056°N 0.00750°W
# 1                            53°17′46″N 02°45′28″W﻿    ﻿53.29611°N 2.75778°W
# 2                            50°28′23″N 04°57′11″W﻿    ﻿50.47306°N 4.95306°W
# 3                            50°38′14″N 04°31′07″W﻿    ﻿50.63722°N 4.51861°W
# 4                            50°17′30″N 05°08′44″W﻿    ﻿50.29167°N 5.14556°W
#
#   coordinates1Northing coordinates1Westing        lat      long
# 0            52°27′02″        00°00′27″W﻿   52.450556 -0.007500
# 1            53°17′46″        02°45′28″W﻿   53.296111 -2.757778
# 2            50°28′23″        04°57′11″W﻿   50.473056 -4.953056
# 3            50°38′14″        04°31′07″W﻿   50.637222 -4.518611
# 4            50°17′30″        05°08′44″W﻿   50.291667 -5.145556

# %%
# df['Coordinates'] = df['Coordinates'].replace('\u00b0',',', regex=True)
# df['Coordinates'] = df['Coordinates'].replace("′",'.', regex=True)
# df['Coordinates'] = df['Coordinates'].replace('″','', regex=True)
df['Coordinates'] = df['Coordinates'].replace('N ',' N, ', regex=True)
df['Coordinates'] = df['Coordinates'].replace('W'," W'", regex=True)

# %%
df.head()
# Out:
#         Wind farm                                        Coordinates  \
# 0        Red Tile                           52.45056° N, 0.00750° W'
# 1        Frodsham  53°17′46″ N, 02°45′28″ W'﻿ / ﻿53.29611° N, 2.7...
# 2      Bears Down  50°28′23″ N, 04°57′11″ W'﻿ / ﻿50.47306° N, 4.9...
# 3  Cold Northcott  50°38′14″ N, 04°31′07″ W'﻿ / ﻿50.63722° N, 4.5...
# 4    Four Burrows  50°17′30″ N, 05°08′44″ W'﻿ / ﻿50.29167° N, 5.1...
#
#   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Model  \
# 0                                       REpower MM82
# 1                                                NaN
# 2                                         Bonus B600
# 3                                        WEG MS3-300
# 4                                         Bonus B300
#
#    Power perturbine(MW)  No.  Cap. (MW)  Online Model  Power per turbine (MW)  \
# 0                  2.00   12      24.00    2007   NaN                     NaN
# 1                  2.65   19      50.35    2017   NaN                     NaN
# 2                  0.60   16       9.60    2001   NaN                     NaN
# 3                  0.30   22       6.80    1993   NaN                     NaN
# 4                  0.30   15       4.50    1998   NaN                     NaN
#
#                                         Coordinates1            Coordinates2  \
# 0  .mw-parser-output .geo-default,.mw-parser-outp...   ﻿52.45056°N 0.00750°W
# 1                            53°17′46″N 02°45′28″W﻿    ﻿53.29611°N 2.75778°W
# 2                            50°28′23″N 04°57′11″W﻿    ﻿50.47306°N 4.95306°W
# 3                            50°38′14″N 04°31′07″W﻿    ﻿50.63722°N 4.51861°W
# 4                            50°17′30″N 05°08′44″W﻿    ﻿50.29167°N 5.14556°W
#
#   coordinates1Northing coordinates1Westing        lat      long
# 0            52°27′02″        00°00′27″W﻿   52.450556 -0.007500
# 1            53°17′46″        02°45′28″W﻿   53.296111 -2.757778
# 2            50°28′23″        04°57′11″W﻿   50.473056 -4.953056
# 3            50°38′14″        04°31′07″W﻿   50.637222 -4.518611
# 4            50°17′30″        05°08′44″W﻿   50.291667 -5.145556

# %%
df.to_csv('windTurbinesOnshoreFinal.csv', index=False)

# %%
df = pd.read_csv('windTurbinesOnshoreFinal.csv')

# %%
import folium
basemap = generatebasemap()

# %%
locations = df[['lat', 'long']]
locationlist = locations.values.tolist()

# %%
locationlist
# Out:
# [[52.45055555555556, -0.0075],
#  [53.29611111111111, -2.7577777777777777],
#  [50.473055555555554, -4.953055555555555],
#  [50.63722222222222, -4.518611111111111],
#  [50.29166666666666, -5.145555555555556],
#  [54.76805555555556, -1.8216666666666663],
#  [54.24611111111111, -3.152222222222222],
#  [53.68277777777777, -0.7947222222222222],
#  [53.68277777777777, -0.7947222222222222],
#  [53.86716666666667, -0.3710555555555555],
#  [54.00972222222222, -0.2541666666666666],
#  [50.962500000000006, 0.8202777777777778],
#  [53.74861111111111, -2.1675],
#  [53.66694444444444, -2.2738888888888886],
#  [53.714444444444446, -2.386111111111111],
#  [52.92611111111111, -0.2163888888888889],
#  [53.42555555555556, -0.08],
#  [53.72555555555556, -0.9208333333333332],
#  [55.098888888888894, -2.198611111111111],
#  [53.53194444444444, -1.6694444444444445],
#  [53.36333333333334, -4.449722222222222],
#  [51.97833333333333, -4.2508333333333335],
#  [51.98805555555556, -4.445277777777778],
#  [51.759166666666665, -4.544444444444444],
#  [51.759166666666665, -4.544444444444444],
#  [52.405, -3.7508333333333335],
#  [51.869166666666665, -4.5569444444444445],
#  [52.30722222222222, -4.028611111111111],
#  [52.455000000000005, -3.9722222222222223],
#  [52.40333333333333, -3.882222222222224],
#  [53.41277777777778, -4.431666666666667],
#  [53.13555555555556, -3.7233333333333336],
#  [53.13555555555556, -3.7233333333333336],
#  [53.114444444444445, -3.4880555555555555],
#  [53.007777777777775, -3.38],
#  [52.961666666666666, -3.467777777777778],
#  [52.900277777777774, -3.5883333333333334],
#  [53.37444444444444, -4.345277777777778],
#  [51.9, -3.1666666666666665],
#  [52.06083333333333, -3.656944444444445],
#  [51.56472222222222, -2.9594444444444448],
#  [52.3675, -3.5641666666666665],
#  [52.55055555555556, -3.600277777777778],
#  [52.55055555555556, -3.600277777777778],
#  [52.64388888888889, -3.679166666666666],
#  [52.436388888888885, -3.413611111111111],
#  [52.58027777777778, -3.433055555555556],
#  [51.562777777777775, -3.4858333333333333],
#  [55.92666666666666, -2.457777777777778],
#  [55.71055555555556, -4.723333333333334],
#  [55.74138888888889, -4.782222222222222],
#  [55.74138888888889, -4.782222222222222],
#  [55.644444444444446, -4.2091666666666665],
#  [55.899166666666666, -2.4619444444444447],
#  [55.899166666666666, -2.4619444444444447],
#  [55.34444444444445, -4.040277777777778],
#  [57.646388888888886, -2.604722222222222],
#  [57.30833333333333, -2.825],
#  [57.41277777777778, -2.728333333333333],
#  [57.42444444444444, -2.642777777777778],
#  [57.473055555555554, -2.238611111111111],
#  [57.3725, -2.401944444444444],
#  [57.31555555555556, -2.114444444444445],
#  [57.44888888888889, -2.1891666666666665],
#  [57.61722222222223, -2.040833333333333],
#  [57.58583333333333, -2.0058333333333334],
#  [57.422777777777775, -2.3344444444444448],
#  [57.62916666666667, -2.585277777777778],
#  [56.83527777777778, -2.399722222222222],
#  [56.84333333333333, -2.398333333333333],
#  [57.40055555555556, -2.0675000000000003],
#  [56.28777777777778, -4.948611111111111],
#  [55.56555555555556, -5.569999999999999],
#  [56.38305555555556, -5.272222222222222],
#  [56.04, -5.156111111111112],
#  [55.62888888888889, -5.559722222222222],
#  [55.49388888888889, -5.679166666666667],
#  [54.96611111111111, -4.766388888888889],
#  [55.21277777777778, -3.1094444444444447],
#  [55.17027777777778, -3.673611111111111],
#  [55.11277777777778, -3.216388888888889],
#  [54.88194444444444, -5.083333333333333],
#  [55.22222222222222, -4.041666666666667],
#  [55.29194444444444, -4.205],
#  [56.48305555555556, -2.8922222222222222],
#  [55.35166666666667, -4.1177777777777775],
#  [55.69166666666666, -4.278333333333333],
#  [55.68722222222222, -4.228611111111111],
#  [58.43722222222222, -3.1919444444444443],
#  [58.004444444444445, -4.531666666666666],
#  [57.80166666666666, -4.332222222222222],
#  [57.80166666666666, -4.332222222222222],
#  [57.42916666666667, -6.455],
#  [57.42722222222222, -6.448611111111111],
#  [58.471944444444446, -3.313333333333333],
#  [58.3, -3.4333333333333336],
#  [58.42944444444444, -3.508611111111111],
#  [57.42916666666667, -6.421666666666667],
#  [57.52972222222222, -4.646388888888889],
#  [57.325, -4.094166666666666],
#  [58.60777777777778, -3.669722222222222],
#  [58.60777777777778, -3.6675],
#  [58.10861111111111, -3.929166666666666],
#  [55.668055555555554, -5.754444444444444],
#  [58.047777777777775, -4.127777777777777],
#  [57.13444444444444, -4.832222222222222],
#  [57.13444444444444, -4.832222222222222],
#  [57.714444444444446, -4.434166666666667],
#  [57.657222222222224, -3.58],
#  [57.44611111111111, -3.476111111111112],
#  [57.53722222222222, -3.3713888888888888],
#  [55.68583333333333, -4.807222222222222],
#  [55.68583333333333, -4.807222222222222],
#  [55.55611111111111, -3.900833333333333],
#  [59.08305555555556, -2.664722222222222],
#  [59.12027777777778, -3.145833333333333],
#  [59.094722222222224, -3.075277777777778],
#  [59.18611111111111, -2.6894444444444447],
#  [56.67944444444444, -3.356388888888889],
#  [56.24888888888889, -3.666944444444444],
#  [55.77222222222222, -2.806666666666666],
#  [55.79833333333333, -2.433888888888889],
#  [55.71555555555556, -3.1397222222222223],
#  [55.76166666666666, -3.013611111111111],
#  [55.895, -2.513055555555556],
#  [55.895, -2.513055555555556],
#  [55.90555555555555, -2.55],
#  [55.8075, -2.8602777777777777],
#  [55.8075, -2.8602777777777777],
#  [55.67305555555555, -2.836388888888889],
#  [60.164722222222224, -1.2361111111111112],
#  [60.164722222222224, -1.2361111111111112],
#  [55.05333333333333, -4.882222222222223],
#  [55.24583333333334, -4.723055555555556],
#  [55.76694444444444, -3.738888888888889],
#  [55.76694444444444, -3.738888888888889],
#  [55.90833333333333, -3.901944444444444],
#  [55.55055555555556, -3.918333333333333],
#  [55.70472222222222, -3.946111111111112],
#  [56.27611111111111, -4.0625],
#  [56.21138888888889, -3.766944444444445],
#  [56.051944444444445, -4.039722222222222],
#  [56.083333333333336, -4.083333333333333],
#  [56.153888888888886, -3.74],
#  [55.80888888888889, -3.599166666666666],
#  [58.17833333333333, -6.4275],
#  [55.26611111111111, -6.443222222222222],
#  [55.03333333333333, -6.256666666666667],
#  [54.85, -6.06],
#  [55.02555555555556, -6.249444444444444],
#  [54.80305555555555, -6.094166666666666],
#  [54.43833333333333, -8.008333333333333],
#  [54.16, -7.62],
#  [54.54805555555556, -7.553888888888888],
#  [54.54805555555556, -7.553888888888888],
#  [54.96, -7.031666666666666],
#  [54.96055555555556, -7.032777777777778],
#  [55.02166666666667, -6.820277777777777],
#  [54.68, -7.403333333333333],
#  [54.7225, -7.374722222222222],
#  [54.705000000000005, -7.591111111111111],
#  [54.45027777777778, -7.3069444444444445],
#  [54.43666666666666, -7.345],
#  [54.43666666666666, -7.345],
#  [54.62694444444445, -7.605833333333333],
#  [54.80833333333333, -7.331666666666666],
#  [54.80833333333333, -7.331666666666666],
#  [54.5075, -7.105277777777777]]

# %%
def generatebasemap(default_location=[52.10, -3.23], default_zoom_start=5):
    basemap = folium.Map(width=1000,height=780,location=default_location, zoom_start=default_zoom_start )
    return basemap

# %%
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f7c7d9a8f469e6240d7796257534dd4 {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 780.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f7c7d9a8f469e6240d7796257534dd4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5f7c7d9a8f469e6240d7796257534dd4 = L.map(
#                 &quot;map_5f7c7d9a8f469e6240d7796257534dd4&quot;,
#                 {
#                     center: [52.1, -3.23],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_230a6c9d3d4edcc1995eddfbc477dfcb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5f7c7d9a8f469e6240d7796257534dd4);
#
#
#             var circle_marker_e0e4d2e786bf018ad7407ff493d85cdd = L.circleMarker(
#                 [52.45055555555556, -0.0075],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#007849&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#007849&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5f7c7d9a8f469e6240d7796257534dd4);
#
#
#             var circle_marker_9aa1f4411657942e3f913a8a905e7cce = L.circleMarker(
#                 [53.29611111111111, -2.7577777777777777],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#007849&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#007849&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5f7c7d9a8f469e6240d7796257534dd4);
#
#
#             var circle_marker_37c31281b7ae9cc68a4bec9fd0952132 = L.circleMarker(
#                 [50.473055555555554, -4.953055555555555],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#007849&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#007849&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5f7c7d9a8f469e6240d7796257534dd4);
#
#
#             var circle_marker_ae6551ea02d59aca79d22eec3078833a = L.circleMarker(
#                 [50.63722222222222, -4.518611111111111],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#007849&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#007849&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5f7c7d9a8f469e6240d7796257534dd4);
#
#
#             var circle_marker_e184591cd8e5797cd8392b00a67b850f = L.circleMarker(
#                 [50.29166666666666, -5.145555555555556],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#007849&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#007849&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5f7c7d9a8f469e6240d7796257534dd4);
#
#
#             var circle_marker_2c20061a61eeb5af8416ff45e4760865 = L.circleMarker(
#                 [54.76805555555556, -1.8216666666666663],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#007849&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#007849&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5f7c7d9a8f469e6240d7796257534dd4);
#
#
#             var circle_marker_e408a7dd6b225b55466b24eda40a6ba0 = L.circleMarker(
#                 [54.24611111111111, -3.1

# %%
for point in range(0, len(locationlist)):
    folium.CircleMarker(locationlist[point],
                        radius= 2,
                        color="#007849",
                        fill=True).add_to(basemap)
    # folium.Marker(locationlist[point]).add_to(basemap)

# %%
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b7e22999e8bb6f0ff5cc9251fa67d28 {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 780.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b7e22999e8bb6f0ff5cc9251fa67d28&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1b7e22999e8bb6f0ff5cc9251fa67d28 = L.map(
#                 &quot;map_1b7e22999e8bb6f0ff5cc9251fa67d28&quot;,
#                 {
#                     center: [52.1, -3.23],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f98bb2b2a49c48c51cf9d946f57ee88 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1b7e22999e8bb6f0ff5cc9251fa67d28);
#
#
#             var circle_marker_fbd59a8f0d72fe05cdbdd92935a9b925 = L.circleMarker(
#                 [52.45055555555556, -0.0075],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#007849&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#007849&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1b7e22999e8bb6f0ff5cc9251fa67d28);
#
#
#             var circle_marker_8a182fc0829e9a377b6bf4f92421eb77 = L.circleMarker(
#                 [53.29611111111111, -2.7577777777777777],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#007849&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#007849&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1b7e22999e8bb6f0ff5cc9251fa67d28);
#
#
#             var circle_marker_94dcb4c911d98a8337aa1f87e77be58b = L.circleMarker(
#                 [50.473055555555554, -4.953055555555555],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#007849&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#007849&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1b7e22999e8bb6f0ff5cc9251fa67d28);
#
#
#             var circle_marker_3ba2b2bfd637901fa2ce215ad0f4b777 = L.circleMarker(
#                 [50.63722222222222, -4.518611111111111],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#007849&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#007849&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1b7e22999e8bb6f0ff5cc9251fa67d28);
#
#
#             var circle_marker_22a9af3ff15b0b5781a511f66bfe6e9c = L.circleMarker(
#                 [50.29166666666666, -5.145555555555556],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#007849&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#007849&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1b7e22999e8bb6f0ff5cc9251fa67d28);
#
#
#             var circle_marker_ba2755b33e9ccbd8aa68982c8a0665c9 = L.circleMarker(
#                 [54.76805555555556, -1.8216666666666663],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#007849&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#007849&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1b7e22999e8bb6f0ff5cc9251fa67d28);
#
#
#             var circle_marker_4f20129a090f118ae9aeae9e3df928b4 = L.circleMarker(
#                 [54.24611111111111, -3.1

# %%
url2 = "https://en.wikipedia.org/wiki/List_of_offshore_wind_farms_in_the_United_Kingdom"

# %%
dfOffshore = scrapeDataAndCreateDataFrame(url2, 0)

# %%
dfOffshore.head()
# Out:
#                           Name   Country  \
# 0                       Barrow   England
# 1                     Beatrice  Scotland
# 2           Beatrice extension  Scotland
# 3  Blyth Offshore Demonstrator   England
# 4                   Burbo Bank   England
#
#                                             Location Cap. (MW) No.  \
# 0  .mw-parser-output .geo-default,.mw-parser-outp...        90  30
# 1     58°06′20″N 03°05′35″W﻿ / ﻿58.10556°N 3.09306°W        10   2
# 2     58°06′20″N 03°05′35″W﻿ / ﻿58.10556°N 3.09306°W       588  84
# 3                                                NaN      41.5   5
# 4      53°29′00″N 3°11′00″W﻿ / ﻿53.48333°N 3.18333°W        90  25
#
#                  Model Projectcommissioning Strike Price Buildcost  Cap.fac.  \
# 0     Vestas V90-3.0MW            July 2006          NaN     £123m  35.9%[4]
# 1           REpower 5M            July 2007          NaN      £35m       20%
# 2   Siemens Gamesa 7MW            July 2019          140   £2,600m       NaN
# 3      Vestas V164-8MW                 2017          NaN       NaN       NaN
# 4  Siemens SWP 3.6–107       September 2007          NaN      £90m    32–35%
#
#   Depthrange (m) km toshore                 Owner      Refs.
# 0          15–20          7                Ørsted   [w 1][5]
# 1             45         23  SSE, Talisman Energy   [w 2][6]
# 2             45         23   SSE Talisman Energy  [7][8][9]
# 3          50-60        6.5        EDF Renewables   [10][11]
# 4            0–6          7                Ørsted  [w 3][12]

# %%
dfOffshore = dfOffshore.drop(['Name', 'Country', 'Owner', 'Refs.'], axis=1)

# %%
dfOffshore[['Coordinates1', 'Coordinates2']] = dfOffshore.Location.str.split("/", expand = True)
print(df.head())
# Out:
#         Wind farm                                        Coordinates  \
# 0        Red Tile                           52.45056° N, 0.00750° W'
# 1        Frodsham  53°17′46″ N, 02°45′28″ W'﻿ / ﻿53.29611° N, 2.7...
# 2      Bears Down  50°28′23″ N, 04°57′11″ W'﻿ / ﻿50.47306° N, 4.9...
# 3  Cold Northcott  50°38′14″ N, 04°31′07″ W'﻿ / ﻿50.63722° N, 4.5...
# 4    Four Burrows  50°17′30″ N, 05°08′44″ W'﻿ / ﻿50.29167° N, 5.1...
#
#   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Model  \
# 0                                       REpower MM82
# 1                                                NaN
# 2                                         Bonus B600
# 3                                        WEG MS3-300
# 4                                         Bonus B300
#
#    Power perturbine(MW)  No.  Cap. (MW)  Online Model  Power per turbine (MW)  \
# 0                  2.00   12      24.00    2007   NaN                     NaN
# 1                  2.65   19      50.35    2017   NaN                     NaN
# 2                  0.60   16       9.60    2001   NaN                     NaN
# 3                  0.30   22       6.80    1993   NaN                     NaN
# 4                  0.30   15       4.50    1998   NaN                     NaN
#
#                                         Coordinates1            Coordinates2  \
# 0  .mw-parser-output .geo-default,.mw-parser-outp...   ﻿52.45056°N 0.00750°W
# 1                            53°17′46″N 02°45′28″W﻿    ﻿53.29611°N 2.75778°W
# 2                            50°28′23″N 04°57′11″W﻿    ﻿50.47306°N 4.95306°W
# 3                            50°38′14″N 04°31′07″W﻿    ﻿50.63722°N 4.51861°W
# 4                            50°17′30″N 05°08′44″W﻿    ﻿50.29167°N 5.14556°W
#
#   coordinates1Northing coordinates1Westing        lat      long
# 0            52°27′02″        00°00′27″W﻿   52.450556 -0.007500
# 1            53°17′46″        02°45′28″W﻿   53.296111 -2.757778
# 2            50°28′23″        04°57′11″W﻿   50.473056 -4.953056
# 3            50°38′14″        04°31′07″W﻿   50.637222 -4.518611
# 4            50°17′30″        05°08′44″W﻿   50.291667 -5.145556

# %%
dfOffshore[['coordinates1Northing', 'coordinates1Westing']] = dfOffshore.Coordinates1.str.split("N ", expand = True)

# %%
dfOffshore.to_csv('windTurbinesOffshore.csv', index=False)

# %%
dataO = pd.read_csv('windTurbinesOffshore.csv')
dfOffshore = dataO

# %%
dfOffshore = dataO

# %%
from dms2dec.dms_convert import dms2dec

dfOffshore['lat'] = dfOffshore.loc[dfOffshore['coordinates1Northing'].notnull(), 'coordinates1Northing'].apply(dms2dec)
dfOffshore['long'] = dfOffshore.loc[dfOffshore['coordinates1Westing'].notnull(), 'coordinates1Westing'].apply(dms2dec)

# %%
dfOffshore.head()
# Out:
#                                          Location  Cap. (MW)  No.  \
# 0   53°59′00″N 3°17′00″W﻿ / ﻿53.98333°N 3.28333°W         90   30
# 1  58°06′20″N 03°05′35″W﻿ / ﻿58.10556°N 3.09306°W         10    2
# 2  58°06′20″N 03°05′35″W﻿ / ﻿58.10556°N 3.09306°W        588   84
# 3   53°29′00″N 3°11′00″W﻿ / ﻿53.48333°N 3.18333°W         90   25
# 4   53°29′00″N 3°11′00″W﻿ / ﻿53.48333°N 3.18333°W        258   32
#
#                  Model Projectcommissioning  Strike Price Buildcost  Cap.fac.  \
# 0     Vestas V90-3.0MW               Jul-06           NaN     £123m  35.9%[4]
# 1           REpower 5M               Jul-07           NaN      £35m       20%
# 2   Siemens Gamesa 7MW               Jul-19         140.0   £2,600m       NaN
# 3  Siemens SWP 3.6–107               Sep-07           NaN      £90m    32–35%
# 4   Vestas V164 8.0 MW               Apr-17           NaN       NaN       NaN
#
#   Depthrange (m)  km toshore  \
# 0          15–20         7.0
# 1             45        23.0
# 2             45        23.0
# 3            0–6         7.0
# 4           6–13         NaN
#
#                                         Coordinates1            Coordinates2  \
# 0  .mw-parser-output .geo-default,.mw-parser-outp...   ﻿53.98333°N 3.28333°W
# 1                            58°06′20″N 03°05′35″W﻿    ﻿58.10556°N 3.09306°W
# 2                            58°06′20″N 03°05′35″W﻿    ﻿58.10556°N 3.09306°W
# 3                             53°29′00″N 3°11′00″W﻿    ﻿53.48333°N 3.18333°W
# 4                             53°29′00″N 3°11′00″W﻿    ﻿53.48333°N 3.18333°W
#
#   coordinates1Northing coordinates1Westing        lat      long
# 0            53°59′00″         3°17′00″W﻿   53.983333 -3.283333
# 1            58°06′20″        03°05′35″W﻿   58.105556 -3.093056
# 2            58°06′20″        03°05′35″W﻿   58.105556 -3.093056
# 3            53°29′00″         3°11′00″W﻿   53.483333 -3.183333
# 4            53°29′00″         3°11′00″W﻿   53.483333 -3.183333

# %%
dfOffshore.to_csv('windTurbinesOffshoreFinal.csv', index=False)

# %%
dataO = pd.read_csv('windTurbinesOffshoreFinal.csv')
dfOffshore = dataO

# %%
locations = df[['lat', 'long']]
locationlist = locations.values.tolist()

# %%
locations2 = dfOffshore[['lat', 'long']]
locationlist2 = locations2.values.tolist()

# %%
locations = df[['lat', 'long']]
locationlist = locations.values.tolist()
for point in range(0, len(locationlist)):
    folium.CircleMarker(locationlist[point],
                        radius= 0.2,
                        color = "#1b9e77",
                        fillColor="black",
                        fill=True).add_to(basemap)

# %%
for point in range(0, len(locationlist2)):
    folium.CircleMarker(locationlist2[point],
                        radius= 0.2,
                        color="#7570b3",
                        fillColor="black",
                        fill=True).add_to(basemap)

# %%
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67980abcc050b49f7391f6c0d2864714 {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 780.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67980abcc050b49f7391f6c0d2864714&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_67980abcc050b49f7391f6c0d2864714 = L.map(
#                 &quot;map_67980abcc050b49f7391f6c0d2864714&quot;,
#                 {
#                     center: [52.1, -3.23],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd296cb6601060aac8e0e75a5b890ec0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_67980abcc050b49f7391f6c0d2864714);
#
#
#             var circle_marker_c9ef615a96294a24e75be525e447871c = L.circleMarker(
#                 [52.45055555555556, -0.0075],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1b9e77&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1b9e77&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_67980abcc050b49f7391f6c0d2864714);
#
#
#             var circle_marker_dd6ab7385237a70a84a8d705972fdad1 = L.circleMarker(
#                 [53.29611111111111, -2.7577777777777777],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1b9e77&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1b9e77&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_67980abcc050b49f7391f6c0d2864714);
#
#
#             var circle_marker_6a0d409334a38d77e4add7c5993f47a2 = L.circleMarker(
#                 [50.473055555555554, -4.953055555555555],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1b9e77&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1b9e77&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_67980abcc050b49f7391f6c0d2864714);
#
#
#             var circle_marker_54f19e6b4c84022b064838180d84a0c8 = L.circleMarker(
#                 [50.63722222222222, -4.518611111111111],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1b9e77&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1b9e77&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_67980abcc050b49f7391f6c0d2864714);
#
#
#             var circle_marker_2ea452c9b2acb8457c7c98f43fce5f46 = L.circleMarker(
#                 [50.29166666666666, -5.145555555555556],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1b9e77&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1b9e77&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_67980abcc050b49f7391f6c0d2864714);
#
#
#             var circle_marker_05a4789da02142c7759817aeb9e80833 = L.circleMarker(
#                 [54.76805555555556, -1.8216666666666663],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1b9e77&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1b9e77&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_67980abcc050b49f7391f6c0d2864714);
#
#
#             var circle_marker_058049f4eb6a639da69e14e6b815d46a = L.circleMarker(
#                 [54.24611111111111, -3.1

# %%
basemap.save("UKWindTurbineLocations.png")

# %%
pip install pyscreenshot
# Out:
# Collecting pyscreenshot
#   Downloading pyscreenshot-3.1-py3-none-any.whl (28 kB)
# Collecting EasyProcess
#   Downloading EasyProcess-1.1-py3-none-any.whl (8.7 kB)
# Collecting entrypoint2
#   Downloading entrypoint2-1.1-py2.py3-none-any.whl (9.9 kB)
# Collecting mss
#   Downloading mss-7.0.1-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.8/76.8 kB 948.3 kB/s eta 0:00:00 0:00:01
# Installing collected packages: entrypoint2, EasyProcess, mss, pyscreenshot
# Successfully installed EasyProcess-1.1 entrypoint2-1.1 mss-7.0.1 pyscreenshot-3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
#!pip install pyscreenshot
import pyscreenshot as ImageGrab
 
im=ImageGrab.grab(bbox=(157,200,1154,800)) # X1,Y1,X2,Y2
#To grab the whole screen, omit the bbox parameter
 
#im.show()
im.save('screenAreGrab.png',format='png')
